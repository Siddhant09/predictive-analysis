# %%
import pandas as pd
import pandas_profiling

pd.set_option('display.max_columns', None)

trips = pd.read_excel('Data.xlsx')
trips
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_20488/3821058060.py:6: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   trips = pd.read_excel('Data.xlsx')
#         GpsProvider           BookingID Market/Regular   \
# 0     CONSENT TRACK  MVCV0000927/082021          Market
# 1           VAMOSYS  VCV00014271/082021         Regular
# 2     CONSENT TRACK  VCV00014382/082021         Regular
# 3           VAMOSYS  VCV00014743/082021         Regular
# 4           VAMOSYS  VCV00014744/082021         Regular
# ...             ...                 ...             ...
# 6875          JTECH        WDSBKTP42751         Regular
# 6876          JTECH        WDSBKTP43203         Regular
# 6877          JTECH        WDSBKTP43021         Regular
# 6878          JTECH        WDSBKTP42685         Regular
# ...

# %%
trips.shape
# Out:
# (6880, 32)

# %%
trips.describe()
# Out:
#           Curr_lat     Curr_lon  TRANSPORTATION_DISTANCE_IN_KM  \
# count  5927.000000  5927.000000                    6168.000000
# mean     18.679995    78.759745                     553.856282
# std       6.075561     4.216357                     758.981836
# min       8.166790    69.657698                       0.000000
# 25%      12.871868    76.891857                      40.000000
# 50%      17.470922    77.843340                     160.000000
# 75%      23.202009    80.018999                     900.000000
# max      32.367928    95.529550                    2954.700000
#
#        Minimum_kms_to_be_covered_in_a_day  Driver_MobileNo
# count                         2820.000000     2.691000e+03
# mean                           250.239362     8.598981e+09
# std                             24.315485     1.131669e+09
# min                              0.000000     6.000546e+09
# 25%                            250.000000     7.651505e+09
# ...

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6880 entries, 0 to 6879
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5927 non-null   object
#  1   BookingID                           6880 non-null   object
#  2   Market/Regular                      6880 non-null   object
#  3   BookingID_Date                      6880 non-null   datetime64[ns]
#  4   vehicle_no                          6880 non-null   object
#  5   Origin_Location                     6880 non-null   object
#  6   Destination_Location                6880 non-null   object
#  7   Org_lat_lon                         6880 non-null   object
#  8   Des_lat_lon                         6880 non-null   object
#  9   Data_Ping_time                      5927 non-null   datetime64[ns]
#  10  Planned_ETA                         6880 non-null   datetime64[ns]
# ...

# %%
# trips_raw = trips.copy()


pandas_profiling.ProfileReport(trips)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-04-27 16:56:14.093903&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
trips.sort_values('trip_start_date')
# Out:
#         GpsProvider     BookingID Market/Regular       BookingID_Date  \
# 6868          JTECH  WDSBKTP44502         Regular 2019-04-15 15:15:13
# 6264            NaN  WDSBKTP49392         Regular 2019-06-10 13:17:44
# 5910            NaN  WDSBKTP41957         Regular 2019-03-18 12:19:22
# 6631            NaN  WDSBKTP41973         Regular 2019-03-18 16:24:18
# 5912            NaN  WDSBKTP41974         Regular 2019-03-18 16:56:02
# ...             ...           ...             ...                 ...
# 2590  KRC LOGISTICS  AEIBK2017781         Regular 2020-10-03 18:26:21
# 2046  CONSENT TRACK  AEIBK2017783         Regular 2020-10-03 19:05:53
# 2591         Garuda  AEIBK2017785         Regular 2020-10-03 20:05:28
# 2592  KRC LOGISTICS  AEIBK2017791         Regular 2020-11-03 10:12:17
# 1862  CONSENT TRACK  AEIBK2017875         Regular 2020-12-03 13:10:21
#
#       vehicle_no                                Origin_Location  \
# ...

# %%
trips.drop(trips.index[[6868, 6264]], inplace = True)
trips.shape
# Out:
# (6878, 32)

# %%
import numpy as np

trips['status'] = trips.ontime.replace({np.NaN, 'G'}, {0, 1})

trips
# Out:
#         GpsProvider           BookingID Market/Regular   \
# 0     CONSENT TRACK  MVCV0000927/082021          Market
# 1           VAMOSYS  VCV00014271/082021         Regular
# 2     CONSENT TRACK  VCV00014382/082021         Regular
# 3           VAMOSYS  VCV00014743/082021         Regular
# 4           VAMOSYS  VCV00014744/082021         Regular
# ...             ...                 ...             ...
# 6875          JTECH        WDSBKTP42751         Regular
# 6876          JTECH        WDSBKTP43203         Regular
# 6877          JTECH        WDSBKTP43021         Regular
# 6878          JTECH        WDSBKTP42685         Regular
# 6879          JTECH        WDSBKTP42858         Regular
#
#               BookingID_Date  vehicle_no  \
# 0    2020-08-17 14:59:01.000    KA590408
# 1    2020-08-27 16:22:22.827  TN30BC5917
# 2    2020-08-27 17:59:24.987  TN22AR2748
# 3    2020-08-28 00:48:24.503  TN28AQ0781
# 4    2020-08-28 01:23:19.243   TN68F1722
# ...

# %%
import tkinter
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.use('TkAgg')
plt.style.use('ggplot')

plt.rcParams['figure.figsize']=(5,5)
plt.pie(trips['status'].value_counts(), explode = (0, 0.05), autopct='%1.1f%%')
plt.title('Percentage of ontime and delay deliveries')
plt.legend(['Delay', 'Ontime'])
plt.show()

# plt.savefig("Graph - Percentage of ontime and delay deliveries.png")

# %%
from geopy import distance

distances_km = []
for row in trips.itertuples(index=False):
   distances_km.append(
       distance.distance(row.Org_lat_lon, row.Des_lat_lon).km
   )

trips['Org_Dest_distance'] = distances_km
trips
# Out:
#         GpsProvider           BookingID Market/Regular   \
# 0     CONSENT TRACK  MVCV0000927/082021          Market
# 1           VAMOSYS  VCV00014271/082021         Regular
# 2     CONSENT TRACK  VCV00014382/082021         Regular
# 3           VAMOSYS  VCV00014743/082021         Regular
# 4           VAMOSYS  VCV00014744/082021         Regular
# ...             ...                 ...             ...
# 6875          JTECH        WDSBKTP42751         Regular
# 6876          JTECH        WDSBKTP43203         Regular
# 6877          JTECH        WDSBKTP43021         Regular
# 6878          JTECH        WDSBKTP42685         Regular
# 6879          JTECH        WDSBKTP42858         Regular
#
#               BookingID_Date  vehicle_no  \
# 0    2020-08-17 14:59:01.000    KA590408
# 1    2020-08-27 16:22:22.827  TN30BC5917
# 2    2020-08-27 17:59:24.987  TN22AR2748
# 3    2020-08-28 00:48:24.503  TN28AQ0781
# 4    2020-08-28 01:23:19.243   TN68F1722
# ...

# %%
for col in trips.columns:
    if trips[col].isna().sum()>0:
        print(col, trips[col].isna().mean().round(4)*100)
# Out:
# GpsProvider 13.84
# Data_Ping_time 13.84
# Current_Location 14.000000000000002
# actual_eta 0.54
# Curr_lat 13.84
# Curr_lon 13.84
# ontime 62.970000000000006
# delay 36.89
# OriginLocation_Code 0.04
# DestinationLocation_Code 0.38999999999999996
# trip_end_date 2.82
# TRANSPORTATION_DISTANCE_IN_KM 10.35
# vehicleType 12.04
# Minimum_kms_to_be_covered_in_a_day 59.0
# Driver_Name 49.830000000000005
# Driver_MobileNo 60.88

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6878 entries, 0 to 6879
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5926 non-null   object
#  1   BookingID                           6878 non-null   object
#  2   Market/Regular                      6878 non-null   object
#  3   BookingID_Date                      6878 non-null   datetime64[ns]
#  4   vehicle_no                          6878 non-null   object
#  5   Origin_Location                     6878 non-null   object
#  6   Destination_Location                6878 non-null   object
#  7   Org_lat_lon                         6878 non-null   object
#  8   Des_lat_lon                         6878 non-null   object
#  9   Data_Ping_time                      5926 non-null   datetime64[ns]
#  10  Planned_ETA                         6878 non-null   datetime64[ns]
# ...

# %%
trips['TRANSPORTATION_DISTANCE_IN_KM']= trips["TRANSPORTATION_DISTANCE_IN_KM"].rolling(min_periods=1, center=True, window=12).mean()
trips['Driver_Name']=trips['Driver_Name'].fillna('Unknown')
trips['vehicleType']=trips['vehicleType'].fillna('Unknown')
trips['actual_eta']=trips['actual_eta'].fillna(method='ffill')
trips['vehicleType']=trips['vehicleType'].fillna('Unknown')
trips.dropna(subset=['trip_end_date'], inplace=True)
trips.dropna(subset=['Current_Location'], inplace=True)
# trips.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5721 entries, 148 to 6879
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5721 non-null   object
#  1   BookingID                           5721 non-null   object
#  2   Market/Regular                      5721 non-null   object
#  3   BookingID_Date                      5721 non-null   datetime64[ns]
#  4   vehicle_no                          5721 non-null   object
#  5   Origin_Location                     5721 non-null   object
#  6   Destination_Location                5721 non-null   object
#  7   Org_lat_lon                         5721 non-null   object
#  8   Des_lat_lon                         5721 non-null   object
#  9   Data_Ping_time                      5721 non-null   datetime64[ns]
#  10  Planned_ETA                         5721 non-null   datetime64[ns]
# ...

# %%
for col in trips.columns:
    if trips[col].isna().sum()>0:
        print(col, trips[col].isna().mean().round(4)*100)
# Out:
# ontime 73.97
# delay 25.82
# OriginLocation_Code 0.05
# DestinationLocation_Code 0.42
# Minimum_kms_to_be_covered_in_a_day 54.379999999999995
# Driver_MobileNo 55.43

# %%
plt.rcParams['figure.figsize']=15,5
plt.subplot(121)
sns.displot(trips['TRANSPORTATION_DISTANCE_IN_KM'], color='black')

plt.subplot(122)
sns.displot(trips['Org_Dest_distance'], color='blue')

plt.suptitle('TRANSPORTATION_DISTANCE_IN_KM Vs Org_Dest_distance')
plt.show()

# plt.savefig("Box Plot - TRANSPORTATION_DISTANCE_IN_KM & Org_Dest_distance.png")

# %%
plt.subplot(121)
sns.boxplot(trips['TRANSPORTATION_DISTANCE_IN_KM'])

plt.subplot(122)
sns.boxplot(trips['Org_Dest_distance'])
plt.show()
# plt.savefig("Box Plot - TRANSPORTATION_DISTANCE_IN_KM & Org_Dest_distance.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings('ignore')

df_cln=trips[['Market/Regular ',
       'vehicle_no',
#        'Current_Location',
       'TRANSPORTATION_DISTANCE_IN_KM',
       'vehicleType', 'Driver_Name',
              'customerID', 'supplierID',
       'Material Shipped', 'status',
       'Origin_Location', 'Destination_Location', 'Org_Dest_distance']]

# df_cln

df_copy=df_cln.copy()

df_cln['vehicle_no']=df_cln.vehicle_no.astype("category").cat.codes
df_cln['customerID']=df_cln.customerID.astype("category").cat.codes
df_cln['supplierID']=df_cln.supplierID.astype("category").cat.codes
df_cln['Origin_Location']=df_cln.Origin_Location.astype("category").cat.codes
df_cln['Destination_Location']=df_cln.Destination_Location.astype("category").cat.codes
# df_cln['Current_Location']=df_cln.Current_Location.astype("category").cat.codes
df_cln['vehicleType']=df_cln.vehicleType.astype("category").cat.codes
df_cln['Material Shipped']=df_cln['Material Shipped'].astype("category").cat.codes
df_cln['Market/Regular ']=df_cln['Market/Regular '].astype("category").cat.codes
df_cln['Driver_Name']=df_cln['Driver_Name'].astype("category").cat.codes

# %%
corr_matrix=df_cln.corr(method ='pearson')
corr_matrix["status"].sort_values(ascending=False)
# Out:
# status                           1.000000
# supplierID                       0.493624
# vehicleType                      0.205597
# vehicle_no                       0.201043
# TRANSPORTATION_DISTANCE_IN_KM    0.108758
# Material Shipped                -0.002902
# Market/Regular                  -0.126872
# Destination_Location            -0.165189
# Origin_Location                 -0.193197
# Org_Dest_distance               -0.234709
# customerID                      -0.247736
# Driver_Name                     -0.252757
# Name: status, dtype: float64

# %%
x=df_cln.drop('status', axis=1)
y=df_cln['status'].values

from sklearn.preprocessing import StandardScaler

#to_scale=df_cln.select_dtypes(include='number').columns.tolist()[1:-1]
sc=StandardScaler()
scaled=sc.fit_transform(x)
x_scl=pd.DataFrame(scaled, columns=x.columns)

# %%
plt.subplot(121)
plt.ylim(-1,1)

means=[]
for i in range(x_scl.shape[1]):
    means.append(np.mean(x_scl.iloc[:,i]))
plt.plot(means, scaley=False)
plt.title('Means of scaled values')

plt.subplot(122)
plt.ylim(0,2)
vars=[]
for i in range(x_scl.shape[1]):
    vars.append(np.var(x_scl.iloc[:,i]))
plt.plot(vars, scaley=False)
plt.title('Varience of scaled values')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_scl, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, roc_auc_score

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4576 entries, 2040 to 5486
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Market/Regular                 4576 non-null   float64
#  1   vehicle_no                     4576 non-null   float64
#  2   TRANSPORTATION_DISTANCE_IN_KM  4576 non-null   float64
#  3   vehicleType                    4576 non-null   float64
#  4   Driver_Name                    4576 non-null   float64
#  5   customerID                     4576 non-null   float64
#  6   supplierID                     4576 non-null   float64
#  7   Material Shipped               4576 non-null   float64
#  8   Origin_Location                4576 non-null   float64
#  9   Destination_Location           4576 non-null   float64
#  10  Org_Dest_distance              4576 non-null   float64
# dtypes: float64(11)
# memory usage: 429.0 KB

# %%
LR=LogisticRegression()
LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
LR.score(X_test, y_test)
# Out:
# 0.8480349344978166

# %%
y_pred_LR=LR.predict(X_test)
y_pred_LR
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
score = accuracy_score(y_test, y_pred_LR)
score
# Out:
# 0.8480349344978166

# %%
plt.rcParams['figure.figsize']=5,5
ax= plt.subplot()
cm = confusion_matrix(y_test, y_pred_LR)
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix - Logistic Regression'); 
ax.xaxis.set_ticklabels(['Delay', 'On time']); ax.yaxis.set_ticklabels(['Delay', 'On time']);
plt.show()

# %%
fpr, tpr, thres = roc_curve(y_test, LR.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.rcParams['figure.figsize']=10,7
plt.plot(fpr, tpr, label = 'ROC Curve' %roc_auc)
plt.plot([0, 1], [0, 1], '--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.title('ROC-AUC graph - Logistic Regression')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions)
score

# %%
plt.rcParams['figure.figsize']=5,5
ax= plt.subplot()
cm = confusion_matrix(y_test, predictions)
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix - Decision Tree Classifier'); 
ax.xaxis.set_ticklabels(['Delay', 'On time']); ax.yaxis.set_ticklabels(['Delay', 'On time']);
plt.show()

# %%
fpr, tpr, thres = roc_curve(y_test, model.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.rcParams['figure.figsize']=10,7
plt.plot(fpr, tpr, label = 'ROC Curve' %roc_auc)
plt.plot([0, 1], [0, 1], '--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.title('ROC-AUC graph - Decision Tree Classifier')
plt.show()
